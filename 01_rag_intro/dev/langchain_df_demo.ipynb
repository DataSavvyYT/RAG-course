# %% [markdown]
# <a href="https://colab.research.google.com/github/DataSavvyYT/RAG-course/blob/main/01_rag_intro/dev/langchain_df_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandasai-litellm openai
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.0.1 Requires-Python <3.12,>=3.8
# ERROR: Could not find a version that satisfies the requirement pandasai-litellm (from versions: none)
# ERROR: No matching distribution found for pandasai-litellm

# %%
import kagglehub
path = kagglehub.dataset_download("toxifarian/tesco-retail-store-clubcard-orders")
# Out:
# ...
# 100%|██████████| 172k/172k [00:00<00:00, 27.8MB/s]
# Extracting files...

# %%
print(path)
# Out:
# /root/.cache/kagglehub/datasets/toxifarian/tesco-retail-store-clubcard-orders/versions/3

# %%
# !ls /root/.cache/kagglehub/datasets/toxifarian/tesco-retail-store-clubcard-orders/versions/3
# Out:
# Tesco.csv

# %%
import pandas as pd

# Load the red wine data
df = pd.read_csv('/root/.cache/kagglehub/datasets/toxifarian/tesco-retail-store-clubcard-orders/versions/3/Tesco.csv')
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import os
import zipfile
import pandas as pd
from google.colab import userdata
from pandasai import SmartDataframe
from pandasai_litellm.litellm import LiteLLM # Faster, modern LLM wrapper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2318516018.py in <cell line: 0>()
#       3 import pandas as pd
#       4 from google.colab import userdata
# ----> 5 from pandasai import SmartDataframe
#       6 from pandasai_litellm.litellm import LiteLLM # Faster, modern LLM wrapper
#
# ModuleNotFoundError: No module named 'pandasai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from openai import OpenAI

# %%
# Initialize OpenAI and SmartDataframe
llm = OpenAI(api_token=userdata.get('OPENAI_API_KEY'), model="gpt-4o-mini")
smart_df = SmartDataframe(df, config={"llm": llm})

# %%
# Query 1: Data Insight
print(smart_df.chat("Which 5 cities have the highest average profit per order?"))

# Query 2: Visualization
smart_df.chat("Create a bar chart of total sales per segment, but only for orders with a discount greater than 20%.")
